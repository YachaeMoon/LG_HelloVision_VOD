# %%
import pandas as pd
import csv

# %%
f = open('DX 데이터스쿨_프로젝트 데이터]/vod_20240301.csv', 'rt', 
                       encoding='utf8')
f_csv = csv.reader(f)

# %%
df = pd.DataFrame(f_csv)

# %%
df
# Out:
#              0                              1         2               3  \
# 0        subsr                       asset_nm     ct_cl  genre_of_ct_cl
# 1     67303000                    맛있는녀석들 168화        기타              기타
# 2     63665000                    선덕여왕(하) 09회     TV드라마              기타
# 3     63665000                    선덕여왕(하) 12회     TV드라마              기타
# 4     60593000           정글의 법칙 in 코타 마나도 06회  TV 연예/오락              기타
# ...        ...                            ...       ...             ...
# 7776  66556000                   괴물(2023)(예고)        영화             드라마
# 7777  63086000                   괴물(2023)(예고)        영화             드라마
# 7778  63017000       만난지3분만에합체 저랑섹스한번하실래요(예고)        영화              성인
# 7779  66056000       만난지3분만에합체 저랑섹스한번하실래요(예고)        영화              성인
# 7780  65954000  피도 눈물도 없이(KBS) 049회(24/03/29)     TV드라마              기타
#
#             4                                                  5  \
# ...

# %%
df = df.rename(columns=df.iloc[0])
df
# Out:
#          subsr                       asset_nm     ct_cl  genre_of_ct_cl  \
# 0        subsr                       asset_nm     ct_cl  genre_of_ct_cl
# 1     67303000                    맛있는녀석들 168화        기타              기타
# 2     63665000                    선덕여왕(하) 09회     TV드라마              기타
# 3     63665000                    선덕여왕(하) 12회     TV드라마              기타
# 4     60593000           정글의 법칙 in 코타 마나도 06회  TV 연예/오락              기타
# ...        ...                            ...       ...             ...
# 7776  66556000                   괴물(2023)(예고)        영화             드라마
# 7777  63086000                   괴물(2023)(예고)        영화             드라마
# 7778  63017000       만난지3분만에합체 저랑섹스한번하실래요(예고)        영화              성인
# 7779  66056000       만난지3분만에합체 저랑섹스한번하실래요(예고)        영화              성인
# 7780  65954000  피도 눈물도 없이(KBS) 049회(24/03/29)     TV드라마              기타
#
#       use_tms                                               SMRY  \
# ...

# %%
df = df.drop(0)

# %%
df
# Out:
#          subsr                       asset_nm     ct_cl genre_of_ct_cl  \
# 1     67303000                    맛있는녀석들 168화        기타             기타
# 2     63665000                    선덕여왕(하) 09회     TV드라마             기타
# 3     63665000                    선덕여왕(하) 12회     TV드라마             기타
# 4     60593000           정글의 법칙 in 코타 마나도 06회  TV 연예/오락             기타
# 5     66619000                            알사탕        키즈             학습
# ...        ...                            ...       ...            ...
# 7776  66556000                   괴물(2023)(예고)        영화            드라마
# 7777  63086000                   괴물(2023)(예고)        영화            드라마
# 7778  63017000       만난지3분만에합체 저랑섹스한번하실래요(예고)        영화             성인
# 7779  66056000       만난지3분만에합체 저랑섹스한번하실래요(예고)        영화             성인
# 7780  65954000  피도 눈물도 없이(KBS) 049회(24/03/29)     TV드라마             기타
#
#      use_tms                                               SMRY  \
# ...

# %%
df.to_csv('vod_20240301.csv', encoding='cp949')
